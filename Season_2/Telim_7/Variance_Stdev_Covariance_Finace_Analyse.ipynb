# %% [markdown]
# ## Variance , Stdev,  Covariance, Finance Analyse

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Excel\Handex Excel\Statistics\Season_2\Telim_7\Pictures\Var_Cov_Fin_Analyse_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 14):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title('Variance , Stdev,  Covariance, Finance Analyse', size=16)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## Variance, Stdev Analyse

# %% [markdown]
# https://finance.yahoo.com/markets/stocks/most-active/

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
# !pip install --upgrade yfinance

# %%
data = pd.DataFrame(yf.download(['NVDA', 'TSLA'], start='2024-01-01', end='2025-06-30', interval='1mo')['Close'])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_20360\1488717512.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = pd.DataFrame(yf.download(['NVDA', 'TSLA'], start='2024-01-01', end='2025-06-30', interval='1mo')['Close'])
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
# Ticker            NVDA        TSLA
# Date
# 2024-01-01   61.499630  187.289993
# 2024-02-01   79.076813  201.880005
# 2024-03-01   90.315811  175.789993
# 2024-04-01   86.367622  183.279999
# 2024-05-01  109.589378  178.080002
# 2024-06-01  123.490845  197.880005
# 2024-07-01  116.983040  232.070007
# 2024-08-01  119.332306  214.110001
# 2024-09-01  121.401649  261.630005
# 2024-10-01  132.729431  249.850006
# 2024-11-01  138.218170  345.160004
# 2024-12-01  134.259079  403.839996
# 2025-01-01  120.050621  404.600006
# 2025-02-01  124.899834  292.980011
# 2025-03-01  108.362511  259.160004
# 2025-04-01  108.912437  282.160004
# 2025-05-01  135.120621  346.459991
# 2025-06-01  157.979034  317.660004

# %%
# !pip install alpha_vantage

# %%
# from alpha_vantage.timeseries import TimeSeries
# import pandas as pd

# # API açarı
# ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')

# def get_clean_monthly_data(symbol):
#     # Aylıq data yüklə
#     data, _ = ts.get_monthly(symbol=symbol)
#     # Tarixləri təmizlə
#     data.index = pd.to_datetime(data.index)
#     data.index = data.index.to_period('M').to_timestamp()
#     data = data.sort_index()
#     # 2025-01-01 ilə 2025-06-01 aralığındakı hissəni seç
#     data = data.loc['2024-01-01':'2025-06-01']
#     # Sütun adlarını təmizlə və sütun adlarına simvol əlavə et
#     data.columns = [col.split('. ', 1)[1] + f'_{symbol}' for col in data.columns]
#     return data

# # Hər simvol üçün ayrıca data çək və təmizlə
# nvda_df = get_clean_monthly_data('NVDA')
# tsla_df = get_clean_monthly_data('TSLA')

# # DataFrame-ləri tarix üzrə birləşdir
# combined = pd.concat([nvda_df[['close_NVDA']], tsla_df[['close_TSLA']]], axis=1)

# # Nəticəni göstər
# combined

# %%
data.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data_pct = data.pct_change()*100
data_pct = data_pct.dropna()
data_pct
# Out:
# Ticker           NVDA       TSLA
# Date
# 2024-02-01  28.580957   7.790065
# 2024-03-01  14.212761 -12.923524
# 2024-04-01  -4.371537   4.260769
# 2024-05-01  26.887108  -2.837187
# 2024-06-01  12.685049  11.118600
# 2024-07-01  -5.269868  17.278149
# 2024-08-01   2.008211  -7.739047
# 2024-09-01   1.734102  22.194201
# 2024-10-01   9.330830  -4.502541
# 2024-11-01   4.135284  38.146886
# 2024-12-01  -2.864378  17.000809
# 2025-01-01 -10.582866   0.188196
# 2025-02-01   4.039307 -27.587739
# 2025-03-01 -13.240468 -11.543452
# 2025-04-01   0.507488   8.874826
# 2025-05-01  24.063536  22.788484
# 2025-06-01  16.917043  -8.312645

# %%
data_pct.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data_pct
# Out:
# Ticker           NVDA       TSLA
# Date
# 2024-02-01  28.580957   7.790065
# 2024-03-01  14.212761 -12.923524
# 2024-04-01  -4.371537   4.260769
# 2024-05-01  26.887108  -2.837187
# 2024-06-01  12.685049  11.118600
# 2024-07-01  -5.269868  17.278149
# 2024-08-01   2.008211  -7.739047
# 2024-09-01   1.734102  22.194201
# 2024-10-01   9.330830  -4.502541
# 2024-11-01   4.135284  38.146886
# 2024-12-01  -2.864378  17.000809
# 2025-01-01 -10.582866   0.188196
# 2025-02-01   4.039307 -27.587739
# 2025-03-01 -13.240468 -11.543452
# 2025-04-01   0.507488   8.874826
# 2025-05-01  24.063536  22.788484
# 2025-06-01  16.917043  -8.312645

# %%
print(data_pct['NVDA'].mean())
print(data_pct['TSLA'].mean())
# Out:
# 6.398385767498821
# 4.364402905193172

# %%
print(data_pct['NVDA'].std())
print(data_pct['TSLA'].std())
# Out:
# 12.604919973774182
# 16.261065971138677
