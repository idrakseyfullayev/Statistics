# %% [markdown]
# ## Hypothesis Two Sample test Variance assumed equal

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Excel\Handex Excel\Statistics\Season_2\Telim_11\Pictures\Distribution_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 16):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for image in image_list:
    plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü
    plt.title("Hypothesis Two Sample test Variance assumed equal", size=16)
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## **"İki filialda hər şey eynidirsə, ortalama da eynidirsə, niyə two sample test aparım?"**

# %% [markdown]
# ### ✅ Cavab:
#
# **Çünki "hər şey eynidir" və "ortalama da eynidir" deyə düşünmək subyektiv və ya təsadüfi müşahidə ola bilər. Statistika isə subyektivliyə yox, sübuta əsaslanır.**
#
# ---
#
# ### 📌 Two sample test (məsələn, t-test) nə üçündür?
#
# İki qrupun (məsələn, filial A və filial B-nin) **real fərqinin olub-olmadığını** yoxlamaq üçündür.
# Sən deyə bilərsən:
#
# * "Ortalama satış bənzərdi"
#   Amma **bu bənzərlik təsadüfdürmü, yoxsa doğrudan da statistik olaraq fərq yoxdur?** — bunu test edir.
#
# ---
#
# ### 🎯 Niyə test aparılır?
#
# | Səbəb                                          | İzah                                                                                                                     |
# | ---------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------ |
# | **1. Təsadüfi fərqləri ayırmaq üçün**          | Ola bilər ki, bu ay filial A 10₼ çox qazandı. Bu **real fərq**dirmi, yoxsa **şans əsəridirmi**?                          |
# | **2. Elmi əsaslı qərar üçün**                  | Gələcəkdə hansı filialın daha çox investisiya alması, hansı strategiyanın uğurlu olduğu statistik sübuta əsaslanmalıdır. |
# | **3. Tək ortalama deyil, yayılma da vacibdir** | Ortalamalar eyni ola bilər, amma biri stabildir (dəyərlər yaxın), digəri dəyişkəndir.                                    |
# | **4. Gələcək fərqləri proqnozlaşdırmaq üçün**  | Əgər test fərq olmadığını göstərirsə, deməli, gələcəkdə də fərq olma ehtimalı azdır.                                     |
#
# ---
#
# ### 🧪 Məsələn:
#
# | Filial | Ortalama Satış (₼) | Std sapma | n (nümunə sayı) |
# | ------ | ------------------ | --------- | --------------- |
# | A      | 100                | 12        | 30              |
# | B      | 101                | 15        | 30              |
#
# Burda **ortalama fərq cəmi 1₼**-dir. Gözlə baxanda "eyni" görünür.
# Amma two sample t-test deyə bilər:
#
# * "Bu fərq statistik olaraq **əhəmiyyətsizdir**" → Doğrudan da eynidir.
# * Yaxud da "Bu fərq **əhəmiyyətlidir**" → Deməli, bu kiçik fərq təsadüfi deyil.
#
# ---
#
# ### 📌 Nəticə:
#
# > “Eyni görünür” ≠ “Statistik olaraq eynidir”
# > Bunu **test etməsən**, yalnız **intuisiya ilə** qərar verirsən.

# %% [markdown]
# ## İki filialın ortalaması eyni p-value < 0.05

# %% [markdown]
# ### ❓ Sual:
#
# - İki filialın ortalaması **eyni çıxıb**
# - Amma **p-value < 0.05** çıxıb.
# - **Necə olur bu? Ortalamalar eynidirsə, niyə fərq əhəmiyyətli çıxsın?**
#
# ---
#
# ### ✅ Cavab:
#
# **Ortalamaların "eyni çıxması" tam dəqiq eyni rəqəm demək deyil — çox yaxın olması da belə başa düşülür. Amma statistik testlər fərqin təsadüfi olub-olmadığını yoxlayır.**
#
# Yəni:
#
# > 🔍 **Orta fərq çox kiçik olsa belə**,
# > əgər **nümunə sayı böyükdürsə** və ya **standart sapma çox azdırsa**,
# > onda bu **kiçik fərq belə əhəmiyyətli** (significant) çıxır.
#
# ---
#
# ### 📊 Texniki olaraq bu baş verə bilər:
#
# #### Məsələn:
#
# | Filial | Ortalama | Std | n    |
# | ------ | -------- | --- | ---- |
# | A      | 100.00   | 0.5 | 1000 |
# | B      | 100.10   | 0.5 | 1000 |
#
# Bu fərq cəmi **0.1₼** olsa da, **p-value < 0.05** çıxacaq. Çünki:
#
# * Nümunə sayı böyükdür
# * Std sapma azdır
# * Belə olan halda, **hətta balaca fərq belə statistik olaraq əhəmiyyətli** görünür.
#
# ---
#
# ### 📌 Qısa qayda:
#
# | Hal                                           | Nəticə                                                                                |
# | --------------------------------------------- | ------------------------------------------------------------------------------------- |
# | **Ortalama fərqi az, amma p-value < 0.05**    | Kiçik fərq **statistik olaraq əhəmiyyətlidir**, çünki **n böyük və ya yayılma azdır** |
# | **Ortalama fərqi böyük, amma p-value > 0.05** | Böyük fərq **statistik deyil**, çünki **n az və ya yayılma çoxdur**                   |
#
# ---
#
# ### 🧠 Nəticə:
#
# > **Orta dəyərlərə baxmaq kifayət deyil.**
# > **p-value bizə deyir: bu fərq təsadüfidirmi, yoxsa real?**

# %% [markdown]
# ## Hipotez Testlərinin Əsas Fəlsəfəsi

# %% [markdown]
# ### 📌 1. **Ortalama eyni çıxıb, amma p-value < 0.05**
#
# > ❓ Bu nə deməkdir?
#
# ### ✅ Açıqlama:
#
# * Ortalamalar **təxminən eynidir**, fərq bəlkə də **0.1₼**, **0.01₼** kimi çox **kiçik bir şeydir**.
# * Amma **statistik test** deyir ki:
#
# > “Bu kiçik fərq **təsadüfən** yaranmayıb. Əgər H0 (eyni olduqları fərziyyəsi) doğru olsaydı, bu nəticə **çox nadir** baş verərdi.”
#
# ### 🎯 Nəticə:
#
# > **Deməli, əslində bu iki filial fərqli işləyib. Sadəcə ortalamaları təsadüfən eyni çıxıb.**
#
# ### 🧠 Analogi:
#
# - Bu sanki **iki tələbənin** imtahandan **eyni bal alması** kimidir.
# - Amma biri **çox çətin sualları** düz yazıb, digəri **asan suallar**. Ortalamaları eyni çıxsa da, **daxili keyfiyyətləri fərqlidir.**
#
# ---
#
# ### 📌 2. **Ortalama fərqlidir, amma p-value > 0.05**
#
# > ❓ Bu nə deməkdir?
#
# ### ✅ Açıqlama:
#
# * Bu halda **sən görünən fərq** görürsən (məsələn, A filialı 105₼, B filialı 100₼).
# * Amma **test deyir**: “Bu fərq **statistik olaraq əhəmiyyətli deyil**. Yəni bu fərq **təsadüfən** də yaranmış ola bilər.”
# * Ola bilər ki:
#
#   * **Nümunə sayı azdır** (n kiçikdirsə, test zəif olur)
#   * **Dəyişkənlik çoxdur** (standart sapma böyükdür)
#
# ### 🎯 Nəticə:
#
# > **Deməli, bu görünən fərq real deyil, sadəcə “şans əsəri” ola bilər. Əslində performanslar bənzərdir.**
#
# ---
#
# ### 📊 İndi bu ikisini cədvəl ilə ümumiləşdirək:
#
# | Ortalama Fərqi   | P-value      | Nəticə                                                                                 |
# | ---------------- | ------------ | -------------------------------------------------------------------------------------- |
# | Eyni / çox yaxın | **p < 0.05** | **Təsadüfən eyni çıxıb. Əslində fərq var.**                                            |
# | Fərqli           | **p > 0.05** | **Fərq təsadüfidir. Əslində fərq yoxdur.**                                             |
# | Eyni             | **p > 0.05** | Eyni çıxıb, p-value da böyük → **Doğrudan da fərq yoxdur.**                            |
# | Fərqli           | **p < 0.05** | Ortalamalar fərqlidir və **statistik olaraq da bu əhəmiyyətlidir** → **Əsl fərq var.** |
#
# ---
#
# ### 🧪 Statistika sənə bunu deməyə kömək edir:
#
# > “Ortalamaya baxıb özün qərar vermə! Mən sənə deyim ki, bu fərq **real**dır, yoxsa **şans əsəridir**.”

# %% [markdown]
# ## ✅ **Excel → Data → Data Analysis** bölməsində olan əsas alətlər və onların izahı:

# %% [markdown]
# ### 1. **Anova: Single Factor**
#
# * **Nədir:** Birdən çox qrupun **ortalamalarının eyni olub-olmadığını** yoxlayır.
# * **Nə üçün:** 3 və ya daha çox qrup arasında **orta fərqi** varsa?
# * **Misal:** 3 filialın ortalama satış həcmi fərqlidir?
# * ✅ **Nümunə:** Bakı, Gəncə, Sumqayıt filiallarının ortalama gündəlik gəliri eynidirmi?
#
# ---
#
# ### 2. **Anova: Two-Factor With Replication**
#
# * **Nədir:** İki fərqli faktorun **orta nəticəyə təsiri** və qarşılıqlı təsirini ölçür.
# * **Data tipi:** Eyni sətirdə bir neçə ölçmə olan data (məsələn, təkrar ölçülər).
# * **Misal:** Müxtəlif dərmanlar və fərqli vaxtlar insanlara necə təsir edir?
# * ✅ **Nümunə:** 3 fərqli dərman, 4 müxtəlif gün ərzində qan təzyiqinə necə təsir edir?
#
# ---
#
# ### 3. **Anova: Two-Factor Without Replication**
#
# * **Nədir:** 2 faktorun təsirini yoxlayır, **təkrar ölçmə yoxdursa**.
# * **Misal:** Müəllim və sinifin tələbənin nəticəsinə təsiri.
# * ✅ **Nümunə:** Fərqli müəllimlər və fərqli məktəblər tələbələrin ballarına necə təsir edir?
#
# ---
#
# ### 4. **Correlation**
#
# * **Nədir:** İki dəyişənin **bir-biri ilə əlaqəsini (r)** ölçür.
# * **Nə üçün:** Güclü əlaqə varmı?
# * **Misal:** Gəlir və xərclər arasında əlaqə varmı?
# * ✅ **Nümunə:** Aylıq gəlir artdıqca, evə edilən xərclər də artırmı?
#
# ---
#
# ### 5. **Covariance**
#
# * **Nədir:** İki dəyişənin **birlikdə necə dəyişdiyini** ölçür.
# * **Fərqi:** Korrelyasiya ilə bənzərdir, amma standartlaşdırılmayıb.
# * **Misal:** Qiymət və satış birlikdə artır, ya biri artır digəri azalır?
# * ✅ **Nümunə:** Reklam xərcləri artdıqda, satışda eyni yöndə dəyişiklik olurmu?
#
# ---
#
# ### 6. **Descriptive Statistics**
#
# * **Nədir:** Ortalama, median, standart sapma və s. statistik göstəriciləri verir.
# * **Nə üçün:** Verilənləri **ümumi tanımaq** üçün.
# * **Misal:** Orta yaş, min-maks dəyərlər, sapmalar və s.
# * ✅ **Nümunə:** Bir şirkətdə işçilərin yaş ortalaması, minimum-maksimum və sapma nə qədərdir?
#
# ---
#
# ### 7. **Exponential Smoothing**
#
# * **Nədir:** Zaman seriyasında **proqnozlar** üçün sadə üsuldur.
# * **Nə üçün:** Trendləri hamarlaşdırmaq və növbəti dəyərləri tapmaq.
# * **Misal:** Satışlar gələn ay necə olacaq?
# * ✅ **Nümunə:** Son 12 ayın satışları əsasında növbəti ayın satışını proqnozlaşdırmaq.
#
# ---
#
# ### 8. **F-Test Two-Sample for Variances**
#
# * **Nədir:** İki qrupun **variansları bərabərdir mi?**
# * **Nə üçün:** t-test-dən əvvəl bəzən bunu yoxlayırlar.
# * **Misal:** Filial A və B satışlarının sabitliyi eynidir?
# * ✅ **Nümunə:** İki şöbənin aylıq satışlarının dəyişkənliyi eyni sabitlikdədirmi?
#
# ---
#
# ### 9. **Fourier Analysis**
#
# * **Nədir:** Siqnal analizi üçün, zaman seriyasındakı **dövriliyi (pattern)** araşdırır.
# * **İxtisaslı istifadə:** Mühəndislik və s. siqnal əsaslı datalarda.
# * ✅ **Nümunə:** Sensor cihazından gələn temperatur siqnalında təkrarlanan dövrilik varmı?
#
# ---
#
# ### 10. **Histogram**
#
# * **Nədir:** Data necə **paylanıb**? (intervala görə).
# * **Nə üçün:** Vizual paylanmanı görmək.
# * **Misal:** Müştəri gəliri hansı aralıqlarda daha çoxdur?
# * ✅ **Nümunə:** Müştərilərin aylıq gəlirini 500-lük intervallara bölüb, paylanmasını göstərmək.
#
# ---
#
# ### 11. **Moving Average**
#
# * **Nədir:** Zaman seriyasında **orta dəyərlərlə proqnoz**.
# * **Nə üçün:** Trendləri izləmək.
# * **Misal:** Son 3 ayın satış ortalamasını tap.
# * ✅ **Nümunə:** Hər ay üçün son 3 ayın satış ortalaması ilə qrafik qurmaq.
#
# ---
#
# ### 12. **Random Number Generation**
#
# * **Nədir:** Simulyasiya və test üçün **təsadüfi data** yaradır.
# * **Nə üçün:** Testlər və modellər üçün random data lazım olduqda.
# * ✅ **Nümunə:** 100 nəfərlik təsadüfi yaş aralığında data yaratmaq (20-60 yaş arası).
#
# ---
#
# ### 13. **Rank and Percentile**
#
# * **Nədir:** Sıralama və yüzdələrini verir.
# * **Misal:** Şagirdlər bal üzrə neçə faizdədir?
# * ✅ **Nümunə:** İmtahan nəticələrində tələbənin 90 balı varsa, neçə faizdən yuxarıdır?
#
# ---
#
# ### 14. **Regression**
#
# * **Nədir:** Asılı və müstəqil dəyişənlər arasındakı **münasibəti** tapır.
# * **Nə üçün:** Proqnozlar və səbəb-nəticə analizləri.
# * **Misal:** Reklam xərcləri satışa necə təsir edir?
# * ✅ **Nümunə:** Reklam büdcəsi əsasında satışları proqnozlaşdırmaq.
#
# ---
#
# ### 15. **Sampling**
#
# * **Nədir:** Böyük datadan **nümunə** çəkir.
# * **Nə üçün:** Test və ya statistik təhlil üçün az sayda müşahidə seçmək.
# * ✅ **Nümunə:** 10,000 müştəri içindən 300 nəfərlik təsadüfi nümunə seçmək.
#
# ---
#
# ### 16. **t-Test: Paired Two Sample for Means**
#
# * **Nədir:** Eyni qrupun **əvvəl-sonra** nəticələrini müqayisə edir.
# * **Misal:** Müalicədən əvvəl və sonra qan təzyiqi dəyişib?
# * ✅ **Nümunə:** İşçilərin təlimdən əvvəl və sonra test balları fərqlidirmi?
#
# ---
#
# ### 17. **t-Test: Two Sample Assuming Equal Variances**
#
# * **Nədir:** İki qrupun ortalaması eyni olub-olmadığını yoxlayır, **variansları bərabər** hesab edir.
# * **Misal:** Filial A və B-nin orta satışları eynidir?
# * ✅ **Nümunə:** Kişi və qadınların orta maaşı fərqlidirmi? (əgər varianslar bərabərdirsə)
#
# ---
#
# ### 18. **t-Test: Two Sample Assuming Unequal Variances**
#
# * **Nədir:** Yuxarıdakının fərqli versiyası, **varianslar fərqli** olsa belə etibarlıdır.
# * **Tövsiyə:** Ən çox **Welch t-test** kimi bu istifadə olunur.
# * ✅ **Nümunə:** İki məktəbdə şagirdlərin ortalama balları fərqlidirmi? (varianslar fərqlidirsə)
#
# ---
#
# ## 📌 BONUS: Hansı Testi Seçim?
#
# | Məqsəd                     | Test                                   |
# | -------------------------- | -------------------------------------- |
# | Ortalamalar eynidirmi?     | t-test                                 |
# | Varianslar eynidirmi?      | F-test                                 |
# | 3+ qrupun ortalaması?      | ANOVA                                  |
# | Dəyişənlər arasında əlaqə? | Correlation                            |
# | Proqnoz vermək?            | Regression                             |
# | Trend izləmək?             | Moving Average / Exponential Smoothing |
# | Data tanımaq?              | Descriptive Statistics                 |

# %% [markdown]
# ## ✅ **Excel → Data → Data Analysis** bölməsindəki testlər və onların Python kod qarşılığı:

# %% [markdown]
# ### 1. **Anova: Single Factor**
#
# * **Nədir:** Birdən çox qrupun ortalamaları eyni olub-olmadığını yoxlayır.
# * **Nə üçün:** 3+ qrup arasında fərq varmı?
# * ✅ **Nümunə:** Bakı, Gəncə, Sumqayıt filiallarının ortalama gündəlik gəliri eynidirmi?
#
# ```python
# from scipy.stats import f_oneway
#
# # Gəlir dataları
# baku = [100, 110, 95, 105]
# ganca = [90, 85, 88, 92]
# sumqayit = [102, 98, 100, 101]
#
# f_stat, p_val = f_oneway(baku, ganca, sumqayit)
# print(f"F-stat: {f_stat}, p-value: {p_val}")
# ```
#
# ---
#
# ### 2. **Anova: Two-Factor With Replication**
#
# * **Nədir:** İki faktorun təsiri və qarşılıqlı təsirini ölçür.
# * ✅ **Nümunə:** 3 fərqli dərman, 4 müxtəlif gün ərzində qan təzyiqinə necə təsir edir?
#
# ```python
# import pandas as pd
# import statsmodels.api as sm
# from statsmodels.formula.api import ols
#
# # Data çərçivəsi (Dərman, Gün, Təzyiq)
# df = pd.read_csv('your_data.csv')  # sütunlar: Drug, Day, BP
#
# model = ols('BP ~ C(Drug) + C(Day) + C(Drug):C(Day)', data=df).fit()
# anova_table = sm.stats.anova_lm(model, typ=2)
# print(anova_table)
# ```
#
# ---
#
# ### 3. **Anova: Two-Factor Without Replication**
#
# * **Nədir:** İki faktorun təsiri, təkrar ölçmə yoxdur.
# * ✅ **Nümunə:** Müəllim və məktəb tələbələrin ballarına necə təsir edir?
#
# ```python
# # Eyni kod, təkrar ölçmə olmayan data ilə
# # model = ols('Score ~ C(Teacher) + C(School)', data=df).fit()
# # print(sm.stats.anova_lm(model, typ=2))
# ```
#
# ---
#
# ### 4. **Correlation**
#
# * **Nədir:** İki dəyişənin əlaqə gücü.
# * ✅ **Nümunə:** Aylıq gəlir artdıqca, xərclər də artırmı?
#
# ```python
# from scipy.stats import pearsonr
#
# income = [1000, 2000, 3000, 4000]
# expense = [900, 1800, 2800, 3900]
#
# r, p = pearsonr(income, expense)
# print(f"Correlation: {r}, p-value: {p}")
# ```
#
# ---
#
# ### 5. **Covariance**
#
# * **Nədir:** İki dəyişənin birlikdə necə dəyişdiyini ölçür.
# * ✅ **Nümunə:** Reklam xərcləri artdıqda, satış da artırmı?
#
# ```python
# import numpy as np
#
# advert = [100, 200, 300]
# sales = [1100, 2100, 3100]
#
# cov_matrix = np.cov(advert, sales)
# print(cov_matrix)
# ```
#
# ---
#
# ### 6. **Descriptive Statistics**
#
# * **Nədir:** Ortalama, min-maks, sapma və s.
# * ✅ **Nümunə:** Şirkətdə işçilərin yaş statistikası.
#
# ```python
# import pandas as pd
#
# ages = [25, 30, 29, 45, 50]
# df = pd.DataFrame(ages, columns=["Age"])
# print(df.describe())
# ```
#
# ---
#
# ### 7. **Exponential Smoothing**
#
# * **Nədir:** Zaman seriyasında proqnoz.
# * ✅ **Nümunə:** Son 12 ayın satışlarına əsasən növbəti ay üçün proqnoz.
#
# ```python
# from statsmodels.tsa.holtwinters import SimpleExpSmoothing
#
# data = [300, 320, 340, 360, 400]
# model = SimpleExpSmoothing(data).fit(smoothing_level=0.2, optimized=False)
# forecast = model.forecast(1)
# print(f"Next month's forecast: {forecast}")
# ```
#
# ---
#
# ### 8. **F-Test Two-Sample for Variances**
#
# * **Nədir:** İki qrupun variansları eynidirmi?
# * ✅ **Nümunə:** İki şöbənin satış sabitliyi müqayisəsi.
#
# ```python
# import numpy as np
#
# a = [100, 105, 98, 102]
# b = [95, 96, 94, 93]
#
# f = np.var(a, ddof=1) / np.var(b, ddof=1)
# print(f"F-statistic: {f}")
# ```
#
# ---
#
# ### 9. **Fourier Analysis**
#
# * **Nədir:** Siqnal və dövrilik analizi.
# * ✅ **Nümunə:** Sensor siqnalında dövri dəyişiklik.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# signal = np.sin(np.linspace(0, 2*np.pi, 100))
# fft_vals = np.fft.fft(signal)
#
# plt.plot(np.abs(fft_vals))
# plt.title("Frequency Spectrum")
# plt.show()
# ```
#
# ---
#
# ### 10. **Histogram**
#
# * **Nədir:** Data paylanmasının qrafiki.
# * ✅ **Nümunə:** Müştəri gəliri interval üzrə paylanması.
#
# ```python
# import matplotlib.pyplot as plt
#
# incomes = [400, 600, 700, 1200, 3000, 2500]
# plt.hist(incomes, bins=[0, 500, 1000, 2000, 3000])
# plt.title("Income Histogram")
# plt.show()
# ```
#
# ---
#
# ### 11. **Moving Average**
#
# * **Nədir:** Zamanla orta dəyişmə.
# * ✅ **Nümunə:** 3 ay üzrə sürüşən ortalama satış.
#
# ```python
# import pandas as pd
#
# sales = [100, 120, 130, 150, 170]
# df = pd.DataFrame(sales, columns=["Sales"])
# df["MA3"] = df["Sales"].rolling(window=3).mean()
# print(df)
# ```
#
# ---
#
# ### 12. **Random Number Generation**
#
# * **Nədir:** Təsadüfi data yaratmaq.
# * ✅ **Nümunə:** 20–60 yaş arası 100 təsadüfi insan yaşı.
#
# ```python
# import numpy as np
#
# random_ages = np.random.randint(20, 61, 100)
# print(random_ages)
# ```
#
# ---
#
# ### 13. **Rank and Percentile**
#
# * **Nədir:** Sıralama və faiz göstəricisi.
# * ✅ **Nümunə:** 90 bal neçə faizdən yuxarıdadır?
#
# ```python
# import pandas as pd
#
# scores = [70, 85, 90, 60, 95]
# df = pd.DataFrame(scores, columns=["Score"])
# df["Rank"] = df["Score"].rank(ascending=False)
# df["Percentile"] = df["Score"].rank(pct=True) * 100
# print(df)
# ```
#
# ---
#
# ### 14. **Regression**
#
# * **Nədir:** Müstəqil və asılı dəyişənlər arasındakı münasibət.
# * ✅ **Nümunə:** Reklam xərcləri satışlara necə təsir edir?
#
# ```python
# import statsmodels.api as sm
#
# x = [100, 200, 300, 400]
# y = [1200, 2200, 3300, 4300]
#
# x = sm.add_constant(x)
# model = sm.OLS(y, x).fit()
# print(model.summary())
# ```
#
# ---
#
# ### 15. **Sampling**
#
# * **Nədir:** Böyük datadan təsadüfi nümunə çəkmək.
# * ✅ **Nümunə:** 10,000 müştəridən 300 nəfər seçmək.
#
# ```python
# import pandas as pd
#
# data = pd.DataFrame({'ID': range(1, 10001)})
# sample = data.sample(n=300, random_state=1)
# print(sample.head())
# ```
#
# ---
#
# ### 16. **t-Test: Paired Two Sample for Means**
#
# * **Nədir:** Eyni qrupun əvvəl və sonra ölçülərinin fərqi.
# * ✅ **Nümunə:** Təlimdən əvvəl və sonra test balları.
#
# ```python
# from scipy.stats import ttest_rel
#
# before = [80, 85, 78, 90]
# after = [85, 88, 82, 95]
#
# t_stat, p = ttest_rel(before, after)
# print(f"T-stat: {t_stat}, p-value: {p}")
# ```
#
# ---
#
# ### 17. **t-Test: Two Sample Assuming Equal Variances**
#
# * **Nədir:** İki qrupun ortalaması eynidirmi? Varianslar bərabərdir.
# * ✅ **Nümunə:** Kişi və qadın maaşı fərqlidirmi?
#
# ```python
# from scipy.stats import ttest_ind
#
# male = [2000, 2200, 2100]
# female = [1900, 2000, 1950]
#
# t_stat, p = ttest_ind(male, female, equal_var=True)
# print(f"T-stat: {t_stat}, p-value: {p}")
# ```
#
# ---
#
# ### 18. **t-Test: Two Sample Assuming Unequal Variances**
#
# * **Nədir:** Varianslar fərqli olsa da ortalamaları müqayisə edir.
# * ✅ **Nümunə:** İki məktəbdə ortalama bal fərqlidirmi?
#
# ```python
# from scipy.stats import ttest_ind
#
# school1 = [80, 85, 83]
# school2 = [75, 70, 78]
#
# t_stat, p = ttest_ind(school1, school2, equal_var=False)
# print(f"T-stat: {t_stat}, p-value: {p}")
# ```
#
# ---
#
# ## 📌 BONUS: Hansı Testi Seçim?
#
# | Məqsəd                     | Test                                   |
# | -------------------------- | -------------------------------------- |
# | Ortalamalar eynidirmi?     | t-test                                 |
# | Varianslar eynidirmi?      | F-test                                 |
# | 3+ qrupun ortalaması?      | ANOVA                                  |
# | Dəyişənlər arasında əlaqə? | Correlation                            |
# | Proqnoz vermək?            | Regression                             |
# | Trend izləmək?             | Moving Average / Exponential Smoothing |
# | Data tanımaq?              | Descriptive Statistics                 |
